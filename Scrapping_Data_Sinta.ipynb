# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from  google_play_scraper import app
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews

result,continuation_token = reviews(
    'com.instagram.android',
    lang = 'id',
    country='id',
    sort = Sort.NEWEST,
    count = 300,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId       userName  \
# 0  fb5aa9ab-ecde-470a-aa71-3932abdf62d7  fiyyaaaw cyts
# 1  9568b12d-7235-4035-9964-c62b1e4b2818   Boby Mahbuby
# 2  9720e953-0a37-43d9-b94e-542492390e61  Muhammad rozi
# 3  82d909db-d346-4f0c-84eb-c036f1263021  Keysia Agiswa
# 4  0610f038-8ef5-4bbe-a511-15afa63c1780    batama Niko
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  mau pasang story dump foto'nya malah ilang di ...      1              0
# 1  Humor IG skrg. Bnyk yg postingan Rasis, jual D...      1              0
# 2                                             Mantap      5              0
# 3                  arsipnya jgn di hapus anjir 😪😪😰😪😥      1              0
# 4                                             Kelasz      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt  \
# 0                 None 2024-09-30 08:49:54         None      None
# 1        350.1.0.46.93 2024-09-30 08:49:16         None      None
# 2                 None 2024-09-30 08:48:19         None      None
# 3        350.1.0.46.93 2024-09-30 08:45:36         None      None
# 4                 None 2024-09-30 08:42:22         None      None
#
#       appVersion
# 0           None
# 1  350.1.0.46.93
# 2           None
# 3  350.1.0.46.93
# 4           None

# %%
len(df_busu.index)
# Out:
# 300

# %%
df_busu[['userName', 'score', 'at', 'content']].head()
# Out:
#                  userName  score                  at  \
# 0                Moli Tkn      5 2024-09-29 22:12:57
# 1  Aurellia Sandi Budiono      1 2024-09-29 22:12:17
# 2              Maulana IM      1 2024-09-29 22:11:19
# 3             fittra kr24      5 2024-09-29 22:09:53
# 4             dindaaptrii      4 2024-09-29 22:03:09
#
#                                              content
# 0                                               Good
# 1  Gajelas banget tiba" akun di banned tanpa alas...
# 2                                   makin gaberes ig
# 3  Suatu hal yang sangat bermanfaat saat mengguna...
# 4                              pls jgn ilangin arsip

# %%
my_df = df_busu[['userName', 'score', 'at', 'content']]
my_df.to_csv("scrapped_data.csv", index = False)
